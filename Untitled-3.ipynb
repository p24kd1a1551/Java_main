# %%
import pandas as pd
import numpy as np
data = {'Name':['A','B','C'], 'Age':[23,25,30], 'Marks':[85,90,88]}
df = pd.DataFrame(data)
print("DataFrame:\n", df)
print("\nColumn Names:", df.columns)
print("\nMean of Marks:", df['Marks'].mean())
